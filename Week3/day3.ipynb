# %% [markdown]
# ### How Web Services work

# %% [markdown]
# The web comprises of 3 elements:
# 1. The client - phone, laptop
# 2. Medium
# 3. Server - processes client requests
# Breakdown
# 1. Client sends a request (using http) through the internet
# 2. Server receives the request
# 3. Server processes the request
# 4. Server sends the response in Json or xml format
# 5. Client receives the response

# %% [markdown]
# ### HTTP - HyperText Transfer Protocol
# It is a set of rules/instructions that guides the transfer of information between machines' over the internet. HTTP methods- instructions that tell the server what to do with the request
# Examples:
# 1. get - retrieves data from the server
# 2. post - submits data from the server
# 3. put - updates- replaces existing resources
# 4. patch - updates, but update specific fields

# %% [markdown]
# ### XML - Extensible Markup Language
# It is just a way to store and organize data. Data is organized in tages- much like in html

# %% [markdown]
# ### Json - Javascript Object Notation
# It is another way the server stores and organizes data(in repsonse to the client's requests) - organizes in dictionary structure

# %% [markdown]
# ### APIS and how they fit in this

# %% [markdown]
# API - Application Programming Interface. A set of rules that defines how 2 applications (server and client)
# going to communicate with each other. It controls how the 2 can exchange data with each other

# %% [markdown]
# ## Common API Status Codes
#     200: Everything went okay, and the result has been returned (if any).
#     301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
#     400: The server thinks you made a bad request. This happens when you send incorrect data or make other client-side errors.
#     401: The server thinks you’re not authenticated. Many APIs require login credentials, so this happens when you don’t send the right credentials to access an API.
#     403: The resource you’re trying to access is forbidden: you don’t have the right permissions to see it.
#     404: The resource you tried to access wasn’t found on the server.
#     503: The server is not ready to handle the request.

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-06-15T12:43:50.242Z', 'error_code': 1001, 'error_message': 'This API Key is invalid.', 'elapsed': 0, 'credit_count': 0}}

# %%
import pandas as pd

# %% [markdown]
# # Assignment
# Create a command-line weather application that retrieves and displays the current weather information for a given city.
#
# Requirements:
#
#     API Access: Use a public weather API like OpenWeatherMap or WeatherAPI.
#     User Input: Allow the user to input a city name.
#     API Request: Make a GET request to the API to retrieve weather data for the given city.
#     Data Handling: Parse the JSON response to extract relevant information (e.g., temperature, weather description, humidity, etc.).
#     Output: Display the weather information in a readable format.
#     Error Handling: Handle errors gracefully, such as invalid city names or API request failures.
#
# Bonus Tasks:
#
#     Multiple Cities: Allow the user to input multiple city names and display the weather for each.
#     Unit Conversion: Provide options to display temperatures in Celsius or Fahrenheit.

# %%
import requests
API_KEY = 'a7f799ab2b02523e67c3bc7e0540c305'
city = str(input('enter city name: '))
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric'
response = requests.get(url)

if response.status_code == 200:
    # Get the JSON data from the response
    data = response.json()

    # Extract the relevant information
    weather = data["weather"][0]["description"]
    temperature = data["main"]["temp"]
    humidity = data["main"]["humidity"]
    wind_speed = data["wind"]["speed"]

    # Print the weather information
    print(f"Current weather in {city}: {weather}")
    print(f"Temperature: {temperature}°C")
    print(f"Humidity: {humidity}%")
    print(f"Wind speed: {wind_speed} m/s")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Current weather in nairobi: overcast clouds
# Temperature: 18.3°C
# Humidity: 72%
# Wind speed: 2.25 m/s
