# %%
import random

def rounds_3():
    choices = ["rock", "paper", "scissors"]
    computer_round = random.randint(0,2)
    computer_score = 0
    player_score = 0

    while True:
        
        player_choice = str(input("Choose either rock, paper or scissors"))
        computer_choice = choices[computer_round]
        if computer_choice == "paper" and player_choice == "rock":
            computer_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif computer_choice == "rock" and player_choice == "scissors":
            computer_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif computer_choice == "scissors" and player_choice == "paper":
            computer_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif player_choice == "paper" and computer_score == "rock":
            player_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif player_choice == "rock" and computer_choice == "scissors":
            player_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif player_choice == "scissors" and computer_choice == "paper":
            player_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        else:
            print("draw")
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        if computer_score == 2 or player_score == 2:
            if computer_score ==2:
                print("Computer wins")
                break
            else:
                print("Player wins")
                break

def round_5():
    choices = ["rock", "paper", "scissors"]
    computer_round = random.randint(0,2)
    computer_score = 0
    player_score = 0

    while True:
        
        player_choice = str(input("Choose either rock, paper or scissors"))
        computer_choice = choices[computer_round]
        if computer_choice == "paper" and player_choice == "rock":
            computer_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif computer_choice == "rock" and player_choice == "scissors":
            computer_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif computer_choice == "scissors" and player_choice == "paper":
            computer_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif player_choice == "paper" and computer_score == "rock":
            player_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif player_choice == "rock" and computer_choice == "scissors":
            player_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        elif player_choice == "scissors" and computer_choice == "paper":
            player_score+=1
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        else:
            print("draw")
            print(f"Computer score: {computer_score}")
            print(f"Player Score: {player_score}")
        if computer_score == 3 or player_score == 3:
            if computer_score ==3:
                print("Computer wins")
                break
            else:
                print("Player wins")
                break


game = str(input("Pick either 3 round game or 5 round game: "))

if game == "3":
    rounds_3()
elif game == "5":
    round_5()
else:
    print("No specified rounds")
# Out:
# draw
# Computer score: 0
# Player Score: 0
# draw
# Computer score: 0
# Player Score: 0
# Computer score: 1
# Player Score: 0
# draw
# Computer score: 1
# Player Score: 0
# draw
# Computer score: 1
# Player Score: 0
# draw
# Computer score: 1
# Player Score: 0
# draw
# Computer score: 1
# Player Score: 0
# draw
# Computer score: 1
# Player Score: 0
# draw
# Computer score: 1
# Player Score: 0
# Computer score: 2
# Player Score: 0
# Computer score: 3
# Player Score: 0
# Computer wins
